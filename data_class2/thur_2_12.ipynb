# %% [markdown]
# ## recap
#
# - mean of all the numbers
# - standard deviation from the mean
# - data preprocessing for machine learning
#     - cleaning the data (preprocessing)
#     - unwanted duplicate columns and rows
#     - fill gaps
#     - formating
# - z score: how far away the outlier is from the mean relative to the standard deviation
# - no.1 models in machine learning is 'regression' and 'xgboost', most important concept is statistics
