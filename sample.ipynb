# %%
print("Hello World!")
# Out:
# Hello World!

# %%
import spacy
import numpy as np
from scipy.spatial.distance import cityblock, euclidean, cosine

# %%
nlp = spacy.load('en_core_web_sm')

# %%
happy_vec = nlp('happy').vector
sad_vec = nlp('sad').vector
angry_vec = nlp('angry').vector

# %%
man_happy_sad = cityblock(happy_vec, sad_vec)
euc_happy_sad = euclidean(happy_vec, sad_vec)
cos_happy_sad = cosine(happy_vec, sad_vec)

# %%
print(man_happy_sad)
print(euc_happy_sad)
print(cos_happy_sad)
# Out:
# 43.497192
# 5.311776638031006
# 0.28871745

# %%
import torch

# %%
with open('data/the_iliad.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
text[5]
# Out:
# 'l'

# %%
text[5:40]
# Out:
# 'liad of Homer\n\n\nTranslated by Alexa'
