# %%
import torch

# %%
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.4792, 0.6700, 0.4622],
#         [0.8914, 0.8673, 0.1253],
#         [0.9331, 0.7755, 0.7275],
#         [0.9777, 0.0793, 0.3574],
#         [0.2768, 0.0396, 0.4374]])

# %%
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
